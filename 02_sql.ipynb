# %% [markdown]
# # Introduction

# %% [markdown]
# # DDL
# ### `create`
#
# ### `alter`
#
# ### `truncate`
#
# ### `drop`
#
# ### `rename`

# %% [markdown]
# # DML
#
# ### `select`
#
# ### `insert`
#
# ### `update`
#
# ### `delete`

# %% [markdown]
# # TCL
#
# ### `commit`
#
# ### `savepoint`
#
# ### `rollback`

# %% [markdown]
# # DCL
#
# ### `grant`
#
# ### `revoke`

# %% [markdown]
# # DQL
#
# ### `select`
#
# ###
