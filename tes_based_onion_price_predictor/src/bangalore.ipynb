# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
pd.set_option("display.max_columns", None)
sns.set_theme(style = "whitegrid")
warnings.filterwarnings("ignore")
plt.rcParams["figure.figsize"] = (20, 5)

# %%
df = pd.read_csv("../data/onion_prices_bangalore_2004_2024.csv")
df.head()
# Out:
#   State Name District Name Market Name           Variety       Group  \
# 0  Karnataka     Bangalore   Bangalore  Bangalore-Samall  Vegetables
# 1  Karnataka     Bangalore   Bangalore  Bangalore-Samall  Vegetables
# 2  Karnataka     Bangalore   Bangalore  Bangalore-Samall  Vegetables
# 3  Karnataka     Bangalore   Bangalore  Bangalore-Samall  Vegetables
# 4  Karnataka     Bangalore   Bangalore  Bangalore-Samall  Vegetables
#
#    Arrivals (Tonnes)  Min Price (Rs./Quintal)  Max Price (Rs./Quintal)  \
# 0              133.0                      400                      440
# 1              230.0                      200                      400
# 2              301.0                      300                      340
# 3              342.0                      800                     1400
# 4              344.0                     1200                     2400
#
#   Modal Price (Rs./Quintal) Reported Date  Unnamed: 10
# 0                       420   06 Sep 2006          NaN
# ...

# %% [markdown]
# # EDA

# %%
df.shape
# Out:
# (12668, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12668 entries, 0 to 12667
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   State Name                 12668 non-null  object
#  1   District Name              12668 non-null  object
#  2   Market Name                12668 non-null  object
#  3   Variety                    12668 non-null  object
#  4   Group                      12668 non-null  object
#  5   Arrivals (Tonnes)          12668 non-null  float64
#  6   Min Price (Rs./Quintal)    12668 non-null  int64
#  7   Max Price (Rs./Quintal)    12668 non-null  int64
#  8   Modal Price (Rs./Quintal)  12668 non-null  object
#  9   Reported Date              12667 non-null  object
#  10  Unnamed: 10                0 non-null      float64
# dtypes: float64(2), int64(2), object(7)
# memory usage: 1.1+ MB

# %%
df.describe().T
# Out:
#                            count         mean          std    min    25%  \
# Arrivals (Tonnes)        12668.0   492.541364   287.567975    0.0  244.0
# Min Price (Rs./Quintal)  12668.0  1056.107515   884.339898   50.0  500.0
# Max Price (Rs./Quintal)  12668.0  1495.384670  1137.914226  200.0  800.0
# Unnamed: 10                  0.0          NaN          NaN    NaN    NaN
#
#                             50%     75%      max
# Arrivals (Tonnes)         488.0   744.0   1200.0
# Min Price (Rs./Quintal)   800.0  1400.0  13000.0
# Max Price (Rs./Quintal)  1200.0  1800.0  22500.0
# Unnamed: 10                 NaN     NaN      NaN

# %%
df["Reported Date"] = pd.to_datetime(df["Reported Date"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12668 entries, 0 to 12667
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   State Name                 12668 non-null  object
#  1   District Name              12668 non-null  object
#  2   Market Name                12668 non-null  object
#  3   Variety                    12668 non-null  object
#  4   Group                      12668 non-null  object
#  5   Arrivals (Tonnes)          12668 non-null  float64
#  6   Min Price (Rs./Quintal)    12668 non-null  int64
#  7   Max Price (Rs./Quintal)    12668 non-null  int64
#  8   Modal Price (Rs./Quintal)  12668 non-null  object
#  9   Reported Date              12667 non-null  datetime64[ns]
#  10  Unnamed: 10                0 non-null      float64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(6)
# memory usage: 1.1+ MB

# %%
df["Reported Month"] = df["Reported Date"].dt.month
df["Reported Year"] = df["Reported Date"].dt.year
df.head()
# Out:
#   State Name District Name Market Name           Variety       Group  \
# 0  Karnataka     Bangalore   Bangalore  Bangalore-Samall  Vegetables
# 1  Karnataka     Bangalore   Bangalore  Bangalore-Samall  Vegetables
# 2  Karnataka     Bangalore   Bangalore  Bangalore-Samall  Vegetables
# 3  Karnataka     Bangalore   Bangalore  Bangalore-Samall  Vegetables
# 4  Karnataka     Bangalore   Bangalore  Bangalore-Samall  Vegetables
#
#    Arrivals (Tonnes)  Min Price (Rs./Quintal)  Max Price (Rs./Quintal)  \
# 0              133.0                      400                      440
# 1              230.0                      200                      400
# 2              301.0                      300                      340
# 3              342.0                      800                     1400
# 4              344.0                     1200                     2400
#
#   Modal Price (Rs./Quintal) Reported Date  Unnamed: 10  Reported Month  \
# ...

# %%
df.drop(columns = ["State Name", "District Name", "Market Name", "Group", "Modal Price (Rs./Quintal)", "Unnamed: 10"], inplace = True)
df.head()
# Out:
#             Variety  Arrivals (Tonnes)  Min Price (Rs./Quintal)  \
# 0  Bangalore-Samall              133.0                      400
# 1  Bangalore-Samall              230.0                      200
# 2  Bangalore-Samall              301.0                      300
# 3  Bangalore-Samall              342.0                      800
# 4  Bangalore-Samall              344.0                     1200
#
#    Max Price (Rs./Quintal) Reported Date  Reported Month  Reported Year
# 0                      440    2006-09-06             9.0         2006.0
# 1                      400    2016-08-18             8.0         2016.0
# 2                      340    2006-10-04            10.0         2006.0
# 3                     1400    2015-06-29             6.0         2015.0
# 4                     2400    2015-08-10             8.0         2015.0

# %%
df.rename(columns = {
    "Variety": "variety",
    "Arrivals (Tonnes)": "arrival_quantity",
    "Min Price (Rs./Quintal)": "min_price",
    "Max Price (Rs./Quintal)": "max_price",
    "Modal Price (Rs./Quintal)": "modal_price",
    "Reported Date": "reported_date",
    "Reported Month": "reported_month",
    "Reported Year": "reported_year"
}, inplace = True)
df.head()
# Out:
#             variety  arrival_quantity  min_price  max_price reported_date  \
# 0  Bangalore-Samall             133.0        400        440    2006-09-06
# 1  Bangalore-Samall             230.0        200        400    2016-08-18
# 2  Bangalore-Samall             301.0        300        340    2006-10-04
# 3  Bangalore-Samall             342.0        800       1400    2015-06-29
# 4  Bangalore-Samall             344.0       1200       2400    2015-08-10
#
#    reported_month  reported_year
# 0             9.0         2006.0
# 1             8.0         2016.0
# 2            10.0         2006.0
# 3             6.0         2015.0
# 4             8.0         2015.0

# %%
df["average_price"] = (df["min_price"] + df["max_price"])/ 2
df.head()
# Out:
#             variety  arrival_quantity  min_price  max_price reported_date  \
# 0  Bangalore-Samall             133.0        400        440    2006-09-06
# 1  Bangalore-Samall             230.0        200        400    2016-08-18
# 2  Bangalore-Samall             301.0        300        340    2006-10-04
# 3  Bangalore-Samall             342.0        800       1400    2015-06-29
# 4  Bangalore-Samall             344.0       1200       2400    2015-08-10
#
#    reported_month  reported_year  average_price
# 0             9.0         2006.0          420.0
# 1             8.0         2016.0          300.0
# 2            10.0         2006.0          320.0
# 3             6.0         2015.0         1100.0
# 4             8.0         2015.0         1800.0

# %%
# unique varieties
print(df["variety"].unique())
print(df["variety"].nunique())
# Out:
# ['Bangalore-Samall' 'Beelary-Red' 'Local' 'Onion' 'Puna']
# 5

# %%
# value counts of each onion variety
df["variety"].value_counts(ascending = False)
# Out:
# variety
# Local               3562
# Puna                3503
# Bangalore-Samall    2741
# Onion               2081
# Beelary-Red          781
# Name: count, dtype: int64

# %%
# average minimum price of each onion variety
df.groupby("variety")["min_price"].mean()
# Out:
# variety
# Bangalore-Samall     518.491426
# Beelary-Red          612.676056
# Local               1154.031443
# Onion               1166.768381
# Puna                1410.328290
# Name: min_price, dtype: float64

# %%
# average maximum price of each onion variety
df.groupby("variety")["max_price"].mean()
# Out:
# variety
# Bangalore-Samall     856.784020
# Beelary-Red          742.893726
# Local               1544.504492
# Onion               1614.935127
# Puna                2041.873537
# Name: max_price, dtype: float64

# %%
# year-wise highest count of onion variety
variety_counts_year = df.groupby(["variety", "reported_year"])["variety"].count()

print(variety_counts_year.to_string(max_rows = None))
# Out:
# variety           reported_year
# Bangalore-Samall  2005.0            49
#                   2006.0           190
#                   2007.0           221
#                   2008.0           146
#                   2009.0           100
#                   2010.0            69
#                   2011.0           167
#                   2012.0           274
#                   2013.0           195
#                   2014.0           181
#                   2015.0           264
#                   2016.0           267
#                   2017.0            57
#                   2018.0             1
#                   2019.0             1
#                   2020.0             1
#                   2022.0           207
#                   2023.0           235
#                   2024.0           116
# Beelary-Red       2004.0           218
#                   2005.0           159
#                   2007.0           117
#                   2008.0           183
# ...

# %%
# month-wise highest count of onion variety
variety_counts_month = df.groupby(["variety", "reported_month"])["variety"].count()

print(variety_counts_month.to_string(max_rows = None))
# Out:
# variety           reported_month
# Bangalore-Samall  1.0               241
#                   2.0               227
#                   3.0               267
#                   4.0               219
#                   5.0               233
#                   6.0               286
#                   7.0               283
#                   8.0               240
#                   9.0               215
#                   10.0              174
#                   11.0              163
#                   12.0              193
# Beelary-Red       1.0                66
#                   2.0                67
#                   3.0                74
#                   4.0                68
#                   5.0                59
#                   6.0                76
#                   7.0                76
#                   8.0                87
#                   9.0                57
#                   10.0               55
# ...

# %%
# year-wise total quantity of onions purchased per variety
variety_quantity_year = df.groupby(["variety", "reported_year"])["arrival_quantity"].sum()

print(variety_quantity_year.to_string(max_rows = None))
# Out:
# variety           reported_year
# Bangalore-Samall  2005.0            23829.0
#                   2006.0            91263.0
#                   2007.0           103351.0
#                   2008.0            69591.0
#                   2009.0            45566.0
#                   2010.0            32893.0
#                   2011.0            74129.0
#                   2012.0           130689.0
#                   2013.0            85999.0
#                   2014.0            88551.0
#                   2015.0           136695.0
#                   2016.0           131943.0
#                   2017.0            28048.0
#                   2018.0              504.0
#                   2019.0              268.0
#                   2020.0              546.0
#                   2022.0           101161.0
#                   2023.0           115834.0
#                   2024.0            63123.0
# Beelary-Red       2004.0           110961.0
#                   2005.0            73899.0
# ...

# %%
# month-wise total quantity of onions purchased per variety
variety_quantity_month = df.groupby(["variety", "reported_month"])["arrival_quantity"].sum()

print(variety_quantity_month.to_string(max_rows = None))
# Out:
# variety           reported_month
# Bangalore-Samall  1.0               117477.0
#                   2.0               113635.0
#                   3.0               128056.0
#                   4.0               105153.0
#                   5.0               105168.0
#                   6.0               144896.0
#                   7.0               133871.0
#                   8.0               120970.0
#                   9.0               106962.0
#                   10.0               73923.0
#                   11.0               79762.0
#                   12.0               94110.0
# Beelary-Red       1.0                34937.0
#                   2.0                30130.0
#                   3.0                38324.0
#                   4.0                30859.0
#                   5.0                26511.0
#                   6.0                37855.0
#                   7.0                32369.0
#                   8.0                44445.0
# ...

# %%
# average price of each variety of onion per year
average_price_year = df.groupby(["variety", "reported_year"])["average_price"].mean()

print(average_price_year.to_string(max_rows = None))
# Out:
# variety           reported_year
# Bangalore-Samall  2005.0            491.938776
#                   2006.0            301.328947
#                   2007.0            656.018100
#                   2008.0            451.061644
#                   2009.0            583.000000
#                   2010.0            985.507246
#                   2011.0            724.625749
#                   2012.0            465.182482
#                   2013.0           1097.076923
#                   2014.0            817.679558
#                   2015.0            928.503788
#                   2016.0            288.932584
#                   2017.0            413.596491
#                   2018.0           2250.000000
#                   2019.0            650.000000
#                   2020.0            850.000000
#                   2022.0            628.140097
#                   2023.0           1055.531915
#                   2024.0           1105.603448
# ...

# %%
# average price of each variety of onion per month
average_price_month = df.groupby(["variety", "reported_month"])["average_price"].mean()

print(average_price_month.to_string(max_rows = None))
# Out:
# variety           reported_month
# Bangalore-Samall  1.0                647.095436
#                   2.0                621.167401
#                   3.0                511.058052
#                   4.0                505.593607
#                   5.0                493.315451
#                   6.0                693.400350
#                   7.0                901.519435
#                   8.0                852.479167
#                   9.0                767.755814
#                   10.0               756.666667
#                   11.0               765.889571
#                   12.0               757.176166
# Beelary-Red       1.0                778.409091
#                   2.0                646.567164
#                   3.0                528.040541
#                   4.0                421.764706
#                   5.0                445.932203
#                   6.0                553.750000
#                   7.0                750.789474
# ...

# %%
# average maximum price of each variety of onion per year
average_maximum_price_year = df.groupby(["variety", "reported_year"])["max_price"].mean()

print(average_maximum_price_year.to_string(max_rows = None))
# Out:
# variety           reported_year
# Bangalore-Samall  2005.0            585.918367
#                   2006.0            331.078947
#                   2007.0            727.873303
#                   2008.0            516.095890
#                   2009.0            647.500000
#                   2010.0           1280.434783
#                   2011.0            861.676647
#                   2012.0            558.613139
#                   2013.0           1310.051282
#                   2014.0           1002.762431
#                   2015.0           1260.795455
#                   2016.0            455.617978
#                   2017.0            577.192982
#                   2018.0           2500.000000
#                   2019.0            700.000000
#                   2020.0            900.000000
#                   2022.0            844.444444
#                   2023.0           1304.255319
#                   2024.0           1386.206897
# ...

# %%
# average maximum price of each variety of onion per month
average_maximum_price_month = df.groupby(["variety", "reported_month"])["max_price"].mean()

print(average_maximum_price_month.to_string(max_rows = None))
# Out:
# variety           reported_month
# Bangalore-Samall  1.0                832.510373
#                   2.0                773.788546
#                   3.0                653.576779
#                   4.0                645.433790
#                   5.0                609.806867
#                   6.0                842.867133
#                   7.0               1032.491166
#                   8.0               1023.000000
#                   9.0                977.744186
#                   10.0               993.160920
#                   11.0               998.404908
#                   12.0               982.797927
# Beelary-Red       1.0                851.212121
#                   2.0                716.716418
#                   3.0                565.405405
#                   4.0                461.029412
#                   5.0                493.220339
#                   6.0                609.342105
#                   7.0                808.815789
# ...

# %%
# average minumum price of each variety of onion per year
average_minimum_price_year = df.groupby(["variety", "reported_year"])["min_price"].mean()

print(average_minimum_price_year.to_string(max_rows = None))
# Out:
# variety           reported_year
# Bangalore-Samall  2005.0            397.959184
#                   2006.0            271.578947
#                   2007.0            584.162896
#                   2008.0            386.027397
#                   2009.0            518.500000
#                   2010.0            690.579710
#                   2011.0            587.574850
#                   2012.0            371.751825
#                   2013.0            884.102564
#                   2014.0            632.596685
#                   2015.0            596.212121
#                   2016.0            122.247191
#                   2017.0            250.000000
#                   2018.0           2000.000000
#                   2019.0            600.000000
#                   2020.0            800.000000
#                   2022.0            411.835749
#                   2023.0            806.808511
#                   2024.0            825.000000
# ...

# %%
# average minumum price of each variety of onion per month
average_minimum_price_month = df.groupby(["variety", "reported_month"])["min_price"].mean()

print(average_minimum_price_month.to_string(max_rows = None))
# Out:
# variety           reported_month
# Bangalore-Samall  1.0                461.680498
#                   2.0                468.546256
#                   3.0                368.539326
#                   4.0                365.753425
#                   5.0                376.824034
#                   6.0                543.933566
#                   7.0                770.547703
#                   8.0                681.958333
#                   9.0                557.767442
#                   10.0               520.172414
#                   11.0               533.374233
#                   12.0               531.554404
# Beelary-Red       1.0                705.606061
#                   2.0                576.417910
#                   3.0                490.675676
#                   4.0                382.500000
#                   5.0                398.644068
#                   6.0                498.157895
#                   7.0                692.763158
# ...

# %% [markdown]
# # Bangalore - Local

# %% [markdown]
# ### Minimum Price

# %% [markdown]
# #### EDA

# %%
# local variety
df_local = df[df["variety"] == "Local"]
df_local.head()
# Out:
#      variety  arrival_quantity  min_price  max_price reported_date  \
# 3522   Local              10.0        950       1000    2011-02-28
# 3523   Local             215.0       1800       2000    2017-08-17
# 3524   Local             230.0        400        800    2016-08-18
# 3525   Local             342.0       1400       1800    2015-06-29
# 3526   Local             344.0       2400       2800    2015-08-10
#
#       reported_month  reported_year  average_price
# 3522             2.0         2011.0          975.0
# 3523             8.0         2017.0         1900.0
# 3524             8.0         2016.0          600.0
# 3525             6.0         2015.0         1600.0
# 3526             8.0         2015.0         2600.0

# %%
# sorting
df_local.sort_values(by = "reported_date", inplace = True)
df_local.reset_index(inplace = True)
df_local.head()
# Out:
#    index variety  arrival_quantity  min_price  max_price reported_date  \
# 0   5296   Local             139.0        600        700    2009-08-21
# 1   5136   Local              34.0        300        600    2009-09-07
# 2   6528   Local             860.0        400       1600    2009-10-08
# 3   6641   Local             315.0        300       1600    2009-10-14
# 4   5567   Local             343.0        500       1800    2009-10-21
#
#    reported_month  reported_year  average_price
# 0             8.0         2009.0          650.0
# 1             9.0         2009.0          450.0
# 2            10.0         2009.0         1000.0
# 3            10.0         2009.0          950.0
# 4            10.0         2009.0         1150.0

# %%
df_local.drop(columns = ["index"], inplace = True)
df_local.head()
# Out:
#   variety  arrival_quantity  min_price  max_price reported_date  \
# 0   Local             139.0        600        700    2009-08-21
# 1   Local              34.0        300        600    2009-09-07
# 2   Local             860.0        400       1600    2009-10-08
# 3   Local             315.0        300       1600    2009-10-14
# 4   Local             343.0        500       1800    2009-10-21
#
#    reported_month  reported_year  average_price
# 0             8.0         2009.0          650.0
# 1             9.0         2009.0          450.0
# 2            10.0         2009.0         1000.0
# 3            10.0         2009.0          950.0
# 4            10.0         2009.0         1150.0

# %%
df_local_min = df_local.copy()
df_local_min.head()
# Out:
#   variety  arrival_quantity  min_price  max_price reported_date  \
# 0   Local             139.0        600        700    2009-08-21
# 1   Local              34.0        300        600    2009-09-07
# 2   Local             860.0        400       1600    2009-10-08
# 3   Local             315.0        300       1600    2009-10-14
# 4   Local             343.0        500       1800    2009-10-21
#
#    reported_month  reported_year  average_price
# 0             8.0         2009.0          650.0
# 1             9.0         2009.0          450.0
# 2            10.0         2009.0         1000.0
# 3            10.0         2009.0          950.0
# 4            10.0         2009.0         1150.0

# %%
df_local_min.drop(columns = ["variety", "arrival_quantity", "max_price", "average_price"], inplace = True)
df_local_min.head()
# Out:
#    min_price reported_date  reported_month  reported_year
# 0        600    2009-08-21             8.0         2009.0
# 1        300    2009-09-07             9.0         2009.0
# 2        400    2009-10-08            10.0         2009.0
# 3        300    2009-10-14            10.0         2009.0
# 4        500    2009-10-21            10.0         2009.0

# %%
df_local_min.isna().sum()
# Out:
# min_price         0
# reported_date     0
# reported_month    0
# reported_year     0
# dtype: int64

# %%
df_local_min["month_plus_year"] = df_local_min["reported_month"] + df_local_min["reported_year"]
mean_monthly_min_price = df_local_min.groupby("month_plus_year")["min_price"].mean()
df_local_min = df_local_min.join(mean_monthly_min_price.rename("mean_monthly_min_price"), on  = "month_plus_year")
df_local_min.head()
# Out:
#    min_price reported_date  reported_month  reported_year  month_plus_year  \
# 0        600    2009-08-21             8.0         2009.0           2017.0
# 1        300    2009-09-07             9.0         2009.0           2018.0
# 2        400    2009-10-08            10.0         2009.0           2019.0
# 3        300    2009-10-14            10.0         2009.0           2019.0
# 4        500    2009-10-21            10.0         2009.0           2019.0
#
#    mean_monthly_min_price
# 0              704.607143
# 1              731.380368
# 2              994.375000
# 3              994.375000
# 4              994.375000

# %%
df_local_min.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3562 entries, 0 to 3561
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   min_price               3562 non-null   int64
#  1   reported_date           3562 non-null   datetime64[ns]
#  2   reported_month          3562 non-null   float64
#  3   reported_year           3562 non-null   float64
#  4   month_plus_year         3562 non-null   float64
#  5   mean_monthly_min_price  3562 non-null   float64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 167.1 KB

# %%
df_local_min["reported_month_year"] = df_local_min["reported_date"].dt.strftime("%m-%Y")
df_local_min["reported_month_year"] = pd.to_datetime(df_local_min["reported_month_year"])
df_local_min.head()
# Out:
#    min_price reported_date  reported_month  reported_year  month_plus_year  \
# 0        600    2009-08-21             8.0         2009.0           2017.0
# 1        300    2009-09-07             9.0         2009.0           2018.0
# 2        400    2009-10-08            10.0         2009.0           2019.0
# 3        300    2009-10-14            10.0         2009.0           2019.0
# 4        500    2009-10-21            10.0         2009.0           2019.0
#
#    mean_monthly_min_price reported_month_year
# 0              704.607143          2009-08-01
# 1              731.380368          2009-09-01
# 2              994.375000          2009-10-01
# 3              994.375000          2009-10-01
# 4              994.375000          2009-10-01

# %%
df_local_min.drop(columns = ["min_price", "reported_date", "reported_month", "reported_year", "month_plus_year"], inplace = True)
df_local_min.rename(columns = {
    "mean_monthly_min_price": "price",
    "reported_month_year": "reported_date"
}, inplace = True)
df_local_min.head()
# Out:
#         price reported_date
# 0  704.607143    2009-08-01
# 1  731.380368    2009-09-01
# 2  994.375000    2009-10-01
# 3  994.375000    2009-10-01
# 4  994.375000    2009-10-01

# %%
# swapping the column order
original_order = list(df_local_min.columns)
new_order = [original_order[1], original_order[0]]
df_local_min = df_local_min[new_order]
df_local_min.head()
# Out:
#   reported_date       price
# 0    2009-08-01  704.607143
# 1    2009-09-01  731.380368
# 2    2009-10-01  994.375000
# 3    2009-10-01  994.375000
# 4    2009-10-01  994.375000

# %%
df_local_min.shape
# Out:
# (3562, 2)

# %%
df_local_min.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3562 entries, 0 to 3561
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   reported_date  3562 non-null   datetime64[ns]
#  1   price          3562 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 55.8 KB

# %%
df_local_min.describe().T
# Out:
#                 count                           mean                  min  \
# reported_date    3562  2017-07-06 14:31:36.013475584  2009-08-01 00:00:00
# price          3562.0                    1154.031443           704.607143
#
#                                25%                  50%                  75%  \
# reported_date  2014-04-01 00:00:00  2017-08-01 00:00:00  2020-12-01 00:00:00
# price                   901.183036          1030.357143          1245.722656
#
#                                max         std
# reported_date  2024-07-01 00:00:00         NaN
# price                   2858.26087  434.895476

# %%
df_local_min.duplicated().sum()
# Out:
# 3392

# %%
df_local_min.drop_duplicates(inplace = True)
df_local_min.head()
# Out:
#   reported_date       price
# 0    2009-08-01  704.607143
# 1    2009-09-01  731.380368
# 2    2009-10-01  994.375000
# 6    2010-07-01  704.607143
# 7    2010-08-01  731.380368

# %%
df_local_min.shape
# Out:
# (170, 2)

# %%
# creating a list of dates
import datetime

start_date = datetime.date(2010, 7, 1)
end_date = datetime.date(2024, 7, 1)
dates = [start_date + datetime.timedelta(days = 31 * i) for i in range((end_date - start_date).days // 31 + 1)]
dates = pd.DataFrame(dates, columns = ["reported_date"])
dates = pd.to_datetime(dates["reported_date"])
dates = pd.DataFrame(dates, columns = ["reported_date"])
dates.head()

dates["reported_date"] = dates["reported_date"].dt.strftime("%Y-%m-01")
dates = pd.to_datetime(dates["reported_date"])
dates.head()
# Out:
# 0   2010-07-01
# 1   2010-08-01
# 2   2010-09-01
# 3   2010-10-01
# 4   2010-11-01
# Name: reported_date, dtype: datetime64[ns]

# %%
# joining "dates" and "df_local_min"
df_local_min = pd.merge(dates, df_local_min, on = "reported_date", how = "outer")
df_local_min.sort_values(by = "reported_date", ascending = True, inplace = True)
df_local_min = df_local_min.tail(-3)
df_local_min.head()
# Out:
#   reported_date        price
# 3    2010-07-01   704.607143
# 4    2010-08-01   731.380368
# 5    2010-09-01   994.375000
# 6    2010-10-01   901.183036
# 7    2010-11-01  1107.840909

# %%
df_local_min.set_index("reported_date", inplace = True)
df_local_min.head()
# Out:
#                      price
# reported_date
# 2010-07-01      704.607143
# 2010-08-01      731.380368
# 2010-09-01      994.375000
# 2010-10-01      901.183036
# 2010-11-01     1107.840909

# %%
plt.figure(figsize = (20, 5))
df_local_min.plot()
plt.show()

# %%
# checking for missing values
df_local_min.isna().sum()
# Out:
# price    2
# dtype: int64

# %%
# imputing the missing values using interpolation
df_local_min["price"].interpolate(method = "linear").plot(label = "interpolated")
df_local_min["price"].plot(label = "original")
plt.show()

# %%
df_local_min["price"] = df_local_min["price"].interpolate(method = "linear")
df_local_min.isna().sum()
# Out:
# price    0
# dtype: int64

# %%
df_local_min["price"].plot(label = "original")
plt.savefig("../artifacts/bangalore_local_time_series.png")

# %%
# outliers
df_local_min["price"].hist(bins = 10).plot()
# Out:
# []

# %%
df_local_min.head(10)
# Out:
#                      price
# reported_date
# 2010-07-01      704.607143
# 2010-08-01      731.380368
# 2010-09-01      994.375000
# 2010-10-01      901.183036
# 2010-11-01     1107.840909
# 2010-12-01     1241.016260
# 2011-01-01     2042.857143
# 2011-02-01      744.565217
# 2011-03-01      791.571429
# 2011-04-01      760.666667

# %% [markdown]
# #### Time Series Decomposition

# %%
# decomposing the time series
import statsmodels.api as sm

# explicitly setting the frequency of the time series
# print(df_local_min.index.freq)
# df_local_min.index = df_local_min.index.asfreq("M")
df_local_min.index.freq = "MS"
# new_index = pd.date_range(start = df_local_min.index.min(), end = df_local_min.index.max(), freq = "M")
# df_local_min.index = new_index

additive_model = sm.tsa.seasonal_decompose(df_local_min["price"], model = "additive")
additive_model.plot();

# %%
# visualizing the residuals (errors) of the additive model
additive_model.resid.hist(bins = 100)
# Out:
# <Axes: >

# %%
# calculating the mean of the errors of the additive model
additive_model.resid.mean()
# Out:
# 6.708748440994153

# %%
# multiplicative decomposition
multiplicative_model = sm.tsa.seasonal_decompose(df_local_min["price"], model = "multiplicative")

multiplicative_model.plot();
plt.savefig("../artifacts/bangalore_local_time_series_decomposition_multiplicative.png")

# %%
# visualizing the residuals of the multiplicative model
multiplicative_model.resid.hist(bins = 100)
# Out:
# <Axes: >

# %%
# calculating the mean of the errors of the multiplicative model
multiplicative_model.resid.mean()
# Out:
# 1.0077081915967252

# %% [markdown]
# #### Dickey-Fuller Test to Check Stationarity

# %%
# checking for stationarity by conducting dicker-fuller test
# H0: Dataset is not stationary.
# H1: Dataset is stationary.

sm.tsa.stattools.adfuller(df_local_min["price"])
# Out:
# (1.401603449314051,
#  0.9971214139590211,
#  11,
#  157,
#  {'1%': -3.472703119504854,
#   '5%': -2.880131672353732,
#   '10%': -2.5766826861130268},
#  2096.0458538889707)

# %%
p_value = sm.tsa.stattools.adfuller(df_local_min["price"])[1]
p_value
# Out:
# 0.9971214139590211

# %%
if p_value <= 0.05:
    print("H1")
else:
    print("H0")
# Out:
# H0

# %% [markdown]
# #### ACF and PACF

# %%
# finding the seasonality by computinf the acf and pacf
# using python package to find acf and pacf
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

plot_acf(df_local_min["price"]);
plt.savefig("../artifacts/bangalore_local_acf.png")

# %%
plot_pacf(df_local_min["price"]);
plt.savefig("../artifacts/bangalore_local_pacf.png")

# %%
# seasonality = 11

# %% [markdown]
# #### Pre Model Building

# %%
# creating a method to compute the performance of the model
from sklearn.metrics import (
    mean_squared_error as mse,
    mean_absolute_error as mae,
    mean_absolute_percentage_error as mape
)

def performance(actual, predicted):
    print('MAE :', round(mae(actual, predicted), 3))
    print('RMSE :', round(mse(actual, predicted)**0.5, 3))
    print('MAPE:', round(mape(actual, predicted), 3))

# %%
# splitting the time series into train and test set
cutoff_date = df_local_min.index[-12]

# train set
train_x = df_local_min.loc[df_local_min.index < cutoff_date].copy()
train_x
# Out:
#                      price
# reported_date
# 2010-07-01      704.607143
# 2010-08-01      731.380368
# 2010-09-01      994.375000
# 2010-10-01      901.183036
# 2010-11-01     1107.840909
# ...                    ...
# 2023-03-01      885.152838
# 2023-04-01      969.683258
# 2023-05-01     1292.592593
# 2023-06-01     1385.882353
# 2023-07-01     1755.921053
#
# [157 rows x 1 columns]

# %%
# text set
test_x = df_local_min.loc[df_local_min.index >= cutoff_date].copy()
test_x
# Out:
#                      price
# reported_date
# 2023-08-01     2858.260870
# 2023-09-01     1606.578947
# 2023-10-01     1730.645161
# 2023-11-01     1973.809524
# 2023-12-01     2163.157895
# 2024-01-01      967.435897
# 2024-02-01      885.152838
# 2024-03-01      969.683258
# 2024-04-01     1292.592593
# 2024-05-01     1385.882353
# 2024-06-01     1755.921053
# 2024-07-01     2858.260870

# %% [markdown]
# #### Mean Model

# %%
# calculating the mean of the train set
train_x["price"].mean()
# Out:
# 1121.8898941342468

# %%
# creating a new column for the predictions
test_x["pred"] = train_x["price"].mean()
test_x
# Out:
#                      price         pred
# reported_date
# 2023-08-01     2858.260870  1121.889894
# 2023-09-01     1606.578947  1121.889894
# 2023-10-01     1730.645161  1121.889894
# 2023-11-01     1973.809524  1121.889894
# 2023-12-01     2163.157895  1121.889894
# 2024-01-01      967.435897  1121.889894
# 2024-02-01      885.152838  1121.889894
# 2024-03-01      969.683258  1121.889894
# 2024-04-01     1292.592593  1121.889894
# 2024-05-01     1385.882353  1121.889894
# 2024-06-01     1755.921053  1121.889894
# 2024-07-01     2858.260870  1121.889894

# %%
# plotting
test_x.plot()
# Out:
# <Axes: xlabel='reported_date'>

# %%
performance(test_x["price"], test_x["pred"])
# Out:
# MAE : 672.625
# RMSE : 868.398
# MAPE: 0.337

# %% [markdown]
# #### Naive Model

# %%
# selecting the value at the latest index in the train set
train_x["price"][-1]
# Out:
# 1755.921052631579

# %%
# creating a new column for the predictions
test_x["pred"] = train_x["price"][-1]
test_x
# Out:
#                      price         pred
# reported_date
# 2023-08-01     2858.260870  1755.921053
# 2023-09-01     1606.578947  1755.921053
# 2023-10-01     1730.645161  1755.921053
# 2023-11-01     1973.809524  1755.921053
# 2023-12-01     2163.157895  1755.921053
# 2024-01-01      967.435897  1755.921053
# 2024-02-01      885.152838  1755.921053
# 2024-03-01      969.683258  1755.921053
# 2024-04-01     1292.592593  1755.921053
# 2024-05-01     1385.882353  1755.921053
# 2024-06-01     1755.921053  1755.921053
# 2024-07-01     2858.260870  1755.921053

# %%
# plotting
test_x.plot()
# Out:
# <Axes: xlabel='reported_date'>

# %%
performance(test_x["price"], test_x["pred"])
# Out:
# MAE : 523.607
# RMSE : 646.547
# MAPE: 0.368

# %% [markdown]
# #### Seasonal Naive Model

# %%
test_x["price"].plot()
train_x["price"][-12: ].plot()
# Out:
# <Axes: xlabel='reported_date'>

# %%
performance(test_x["price"], train_x["price"][-12: ])
# Out:
# MAE : 419.076
# RMSE : 603.819
# MAPE: 0.217

# %% [markdown]
# #### Drift Model

# %%
# last value in the train set
y_t = train_x["price"][-1]
# computing m (slope)
m = (y_t -  train_x["price"][0])/ len(train_x)
# number of future values
h = np.linspace(0, len(test_x) - 1, len(test_x))
# creating a new column for the predictions
test_x["pred"] = y_t + m * h
test_x
# Out:
#                      price         pred
# reported_date
# 2023-08-01     2858.260870  1755.921053
# 2023-09-01     1606.578947  1762.617320
# 2023-10-01     1730.645161  1769.313587
# 2023-11-01     1973.809524  1776.009853
# 2023-12-01     2163.157895  1782.706120
# 2024-01-01      967.435897  1789.402387
# 2024-02-01      885.152838  1796.098654
# 2024-03-01      969.683258  1802.794921
# 2024-04-01     1292.592593  1809.491188
# 2024-05-01     1385.882353  1816.187455
# 2024-06-01     1755.921053  1822.883722
# 2024-07-01     2858.260870  1829.579989

# %%
# plotting
test_x.plot()
# Out:
# <Axes: xlabel='reported_date'>

# %%
performance(test_x["price"], test_x["pred"])
# Out:
# MAE : 540.347
# RMSE : 654.434
# MAPE: 0.386

# %% [markdown]
# #### Moving Average Model

# %%
# creating a copy of "df_local_min"
df_local_min_copy = df_local_min.copy()
df_local_min_copy.head()
# Out:
#                      price
# reported_date
# 2010-07-01      704.607143
# 2010-08-01      731.380368
# 2010-09-01      994.375000
# 2010-10-01      901.183036
# 2010-11-01     1107.840909

# %%
# appending future dates to "df_local_min_copy"
df_local_min_copy = pd.concat([df_local_min_copy, pd.DataFrame(index = pd.date_range(start = df_local_min.index[-1], periods = 13, freq = "MS")[1: ])])
df_local_min_copy.tail(20)
# Out:
#                   price
# 2023-12-01  2163.157895
# 2024-01-01   967.435897
# 2024-02-01   885.152838
# 2024-03-01   969.683258
# 2024-04-01  1292.592593
# 2024-05-01  1385.882353
# 2024-06-01  1755.921053
# 2024-07-01  2858.260870
# 2024-08-01          NaN
# 2024-09-01          NaN
# 2024-10-01          NaN
# 2024-11-01          NaN
# 2024-12-01          NaN
# 2025-01-01          NaN
# 2025-02-01          NaN
# 2025-03-01          NaN
# 2025-04-01          NaN
# 2025-05-01          NaN
# 2025-06-01          NaN
# 2025-07-01          NaN

# %%
# calculating 3 months rolling window
# dropping all the null values
pred = df_local_min_copy["price"].dropna().values
pred
# Out:
# array([ 704.60714286,  731.3803681 ,  994.375     ,  901.18303571,
#        1107.84090909, 1241.01626016, 2042.85714286,  744.56521739,
#         791.57142857,  760.66666667,  711.41025641,  704.60714286,
#         731.3803681 ,  994.375     ,  901.18303571, 1107.84090909,
#        1241.01626016, 1245.72265625,  744.56521739,  791.57142857,
#         760.66666667,  711.41025641,  704.60714286,  731.3803681 ,
#         994.375     ,  901.18303571, 1107.84090909, 1241.01626016,
#        1245.72265625, 1030.35714286,  791.57142857,  760.66666667,
#         711.41025641,  704.60714286,  731.3803681 ,  994.375     ,
#         901.18303571, 1107.84090909, 1241.01626016, 1245.72265625,
#        1084.03732639,  922.35199653,  760.66666667,  711.41025641,
#         704.60714286,  731.3803681 ,  994.375     ,  901.18303571,
#        1107.84090909, 1241.01626016, 1245.72265625, 1030.35714286,
#         967.43589744,  885.15283843,  711.41025641,  704.60714286,
# ...

# %%
# calculating the moving average
for i in range(12):
    # the last 3 elements of pred are extracted
    # the average of these 3 elements is calculated
    # the calculated average is appended to the end of pred, effectively extending the array
    pred = np.append(pred, pred[-11: ].mean())

# looking at the last 20 months
pred[-20: ]
# Out:
# array([2163.15789474,  967.43589744,  885.15283843,  969.68325792,
#        1292.59259259, 1385.88235294, 1755.92105263, 2858.26086957,
#        1599.01094443, 1598.32294416, 1586.2936517 , 1551.06493605,
#        1495.42012162, 1543.41868746, 1603.26103737, 1660.85901732,
#        1694.3377832 , 1722.37918595, 1719.32992535, 1615.7907486 ])

# %%
# rounding off the predicted values to have 1 integer value after the decimal
pred = pred.round(1)
pred[-20: ]
# Out:
# array([2163.2,  967.4,  885.2,  969.7, 1292.6, 1385.9, 1755.9, 2858.3,
#        1599. , 1598.3, 1586.3, 1551.1, 1495.4, 1543.4, 1603.3, 1660.9,
#        1694.3, 1722.4, 1719.3, 1615.8])

# %%
# visualizing
df_local_min_copy["pred"] = pred
df_local_min_copy.loc[~df_local_min_copy["price"].isna(), "pred"] = np.nan
df_local_min_copy.tail(100).plot()
plt.show()

# %%
df_local_min_copy.tail(13)
# Out:
#                  price    pred
# 2024-07-01  2858.26087     NaN
# 2024-08-01         NaN  1599.0
# 2024-09-01         NaN  1598.3
# 2024-10-01         NaN  1586.3
# 2024-11-01         NaN  1551.1
# 2024-12-01         NaN  1495.4
# 2025-01-01         NaN  1543.4
# 2025-02-01         NaN  1603.3
# 2025-03-01         NaN  1660.9
# 2025-04-01         NaN  1694.3
# 2025-05-01         NaN  1722.4
# 2025-06-01         NaN  1719.3
# 2025-07-01         NaN  1615.8

# %% [markdown]
# #### Triple Exponential Smoothing

# %%
model = sm.tsa.ExponentialSmoothing(df_local_min["price"], trend = "add", seasonal = "add")
model_fit = model.fit(smoothing_level = 1/ 22, smoothing_trend = 0.07, smoothing_seasonal = 0.90)
performance(df_local_min["price"], model_fit.fittedvalues)
model_fit.fittedvalues.plot(label = "fitted")
df_local_min["price"].plot(label = "original")
plt.legend()
plt.savefig("../artifacts/bangalore_local_model_training.png")
# Out:
# MAE : 187.874
# RMSE : 331.316
# MAPE: 0.145

# %%
# predicting
pred = model_fit.forecast(steps = 12)
df_local_min.tail(100).plot(label = "actual")
pred.plot(label = "predicted")
plt.legend()
plt.savefig("../artifacts/bangalore_local_model_forecast.png")

# %%
pred = pd.DataFrame(pred, columns = ["predicted_price"])
pred
# Out:
#             predicted_price
# 2024-08-01      2891.016674
# 2024-09-01      1823.976486
# 2024-10-01      1884.983259
# 2024-11-01      2114.721238
# 2024-12-01      2304.703962
# 2025-01-01      1136.547965
# 2025-02-01      1067.285798
# 2025-03-01      1148.121962
# 2025-04-01      1451.718917
# 2025-05-01      1560.129961
# 2025-06-01      1906.907843
# 2025-07-01      1995.991986
